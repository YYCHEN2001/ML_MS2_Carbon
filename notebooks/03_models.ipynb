# %%
import pandas as pd
from scripts.evaluate_model import ModelEvaluator
from sklearn.model_selection import train_test_split
from tabpfn import TabPFNRegressor
from xgboost import XGBRegressor


data = pd.read_csv('../data/processed/dataset_reduced.csv')
data
# Out:
#       Z  Period  Group    EN    CR  CM_type  CM_morph  MS2_morph  CP_morph  \
# 0    23       4      5  1.63  1.44        0         0          1         0
# 1    23       4      5  1.63  1.44        0         0          1         0
# 2    23       4      5  1.63  1.44        0         0          1         0
# 3    23       4      5  1.63  1.44        0         0          1         0
# 4    23       4      5  1.63  1.44        0         0          1         0
# ..   ..     ...    ...   ...   ...      ...       ...        ...       ...
# 577  74       6      6  1.70  1.50        1         1          2         1
# 578  74       6      6  1.70  1.50        1         1          2         1
# 579  74       6      6  1.70  1.50        1         1          2         1
# 580  74       6      6  1.70  1.50        1         1          2         1
# 581  74       6      6  1.70  1.50        1         1          2         1
#
#       SSA    C Cation Anion   PW    CD     Cs
# 0     5.5  6.0      K    OH  0.5   1.0  152.0
# 1     5.5  6.0      K    OH  0.5   2.0  145.0
# 2     5.5  6.0      K    OH  0.5   5.0  136.0
# 3     5.5  6.0      K    OH  0.5  10.0  120.0
# 4     5.5  6.0      K    OH  0.5  15.0   90.0
# ..    ...  ...    ...   ...  ...   ...    ...
# 577  10.8  1.0      K    OH  0.5   1.0  600.0
# 578  10.8  1.0      K    OH  0.5   2.0  527.0
# 579  10.8  1.0      K    OH  0.5   4.0  476.0
# 580  10.8  1.0      K    OH  0.5   8.0  391.0
# 581  10.8  1.0      K    OH  0.5  10.0  340.0
#
# [582 rows x 16 columns]

# %%
# 对 Cation, Anion 进行One-hot编码
data_encoded = pd.get_dummies(data, columns=['Cation', 'Anion'])

# 划分训练集和测试集
data_encoded['target_class'] = pd.qcut(data_encoded['Cs'], q=10, labels=False)
X = data_encoded.drop(['Cs', 'target_class'], axis=1)
y = data_encoded['Cs']
stratify_column = data_encoded['target_class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21, stratify=stratify_column)
X_train
# Out:
#       Z  Period  Group    EN    CR  CM_type  CM_morph  MS2_morph  CP_morph  \
# 434  42       5      6  2.16  1.46        0         0          1         0
# 519  50       5     14  1.96  1.40        2         2          3         1
# 172  27       4      9  1.88  1.18        3         3          3         4
# 165  42       5      6  2.16  1.46        0         0          2         0
# 76   26       4      8  1.83  1.24        2         2          3         1
# ..   ..     ...    ...   ...   ...      ...       ...        ...       ...
# 353  28       4     10  1.91  1.17        3         3          5         3
# 320  28       4     10  1.91  1.17        1         1          2         1
# 531  74       6      6  1.70  1.50        0         0          3         0
# 150  27       4      9  1.88  1.18        0         0          5         0
# 81   26       4      8  1.83  1.24        2         2          4         1
#
#         SSA    C    PW    CD  Cation_H  Cation_K  Cation_Li  Cation_Na  \
# 434   21.10  1.0  1.00   1.5     False     False      False       True
# 519   41.82  2.0  0.45   0.3     False      True      False      False
# 172  253.80  6.0  0.50   1.0     False      True      False      False
# 165   58.20  2.0  0.50   2.0     False      True      False      False
# 76   135.00  2.0  1.10  20.0     False      True      False      False
# ..      ...  ...   ...   ...       ...       ...        ...        ...
# 353   24.00  2.0  0.40  15.0     False      True      False      False
# 320   72.60  3.0  0.40   5.0     False      True      False      False
# 531   16.64  2.0  0.60   6.0     False      True      False      False
# 150  113.90  2.0  0.50   1.0     False      True      False      False
# 81   165.00  2.0  1.10  15.0     False      True      False      False
#
#      Anion_OH  Anion_SO4
# 434     False       True
# 519      True      False
# 172      True      False
# 165      True      False
# 76       True      False
# ..        ...        ...
# 353      True      False
# 320      True      False
# 531      True      False
# 150      True      False
# 81       True      False
#
# [465 rows x 19 columns]

# %%
# 初始化TabPFN回归模型
model = TabPFNRegressor()

# 训练模型
model.fit(X_train, y_train)

# 预测
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
evaluator = ModelEvaluator(model_name='TabPFN', y_train=y_train, y_train_pred=y_train_pred, y_test=y_test, y_test_pred=y_test_pred)
evaluator.metrics_to_dataframe()
# Out:
#     model  R2_train  MAE_train  MAPE_train  RMSE_train  R2_test  MAE_test  \
# 0  TabPFN     0.998       8.43        2.76       16.07    0.987     25.28
#
#    MAPE_test  RMSE_test
# 0       7.41      43.87

# %%
evaluator.plot_actual_vs_predicted()
